# %%
import pandas as pd
import numpy as np
import billboard

# %%
chart = billboard.ChartData('hot-100')

# %%
chart.

# %%
chart.json()
# Out:
# '{\n    "_max_retries": 3,\n    "_timeout": 25,\n    "date": "2020-02-22",\n    "entries": [\n        {\n            "artist": "Roddy Ricch",\n            "image": null,\n            "isNew": false,\n            "lastPos": 1,\n            "peakPos": 1,\n            "rank": 1,\n            "title": "The Box",\n            "weeks": 10\n        },\n        {\n            "artist": "Future Featuring Drake",\n            "image": null,\n            "isNew": false,\n            "lastPos": 2,\n            "peakPos": 2,\n            "rank": 2,\n            "title": "Life Is Good",\n            "weeks": 5\n        },\n        {\n            "artist": "Post Malone",\n            "image": null,\n            "isNew": false,\n            "lastPos": 3,\n            "peakPos": 1,\n            "rank": 3,\n            "title": "Circles",\n            "weeks": 24\n        },\n        {\n            "artist": "Maroon 5",\n            "image": null,\n            "isNew": false,\n            "lastPos": 4
# ...

# %%
import json

# %%
json.loads(chart.json())
# Out:
# {'_max_retries': 3,
#  '_timeout': 25,
#  'date': '2020-02-22',
#  'entries': [{'artist': 'Roddy Ricch',
#    'image': None,
#    'isNew': False,
#    'lastPos': 1,
#    'peakPos': 1,
#    'rank': 1,
#    'title': 'The Box',
#    'weeks': 10},
#   {'artist': 'Future Featuring Drake',
#    'image': None,
#    'isNew': False,
#    'lastPos': 2,
#    'peakPos': 2,
#    'rank': 2,
#    'title': 'Life Is Good',
#    'weeks': 5},
#   {'artist': 'Post Malone',
#    'image': None,
#    'isNew': False,
#    'lastPos': 3,
#    'peakPos': 1,
#    'rank': 3,
#    'title': 'Circles',
#    'weeks': 24},
#   {'artist': 'Maroon 5',
#    'image': None,
#    'isNew': False,
#    'lastPos': 4,
#    'peakPos': 2,
#    'rank': 4,
#    'title': 'Memories',
#    'weeks': 21},
#   {'artist': 'Tones And I',
#    'image': None,
#    'isNew': False,
#    'lastPos': 5,
#    'peakPos': 5,
#    'rank': 5,
#    'title': 'Dance Monkey',
#    'weeks': 19},
#   {'artist': 'Dua Lipa',
#    'image': None,
# ...

# %%
chart.date
# Out:
# '2020-02-22'

# %%
1 if '' else 0
# Out:
# 0

# %%
from datetime import datetime

# %%
type(datetime.now())
# Out:
# datetime.datetime

# %%
if True print('yes')
# Out:
#   File "<ipython-input-34-f84254ec933b>", line 1
#     if True print('yes')
#                 ^
# SyntaxError: invalid syntax
